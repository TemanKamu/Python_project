# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# Input Data
capital = 5
deposit = 1
numberPeriods = 5
returnPeriods = 1

# %%
# Define Function
def initial_capital_compounding(capital, numberPeriods, returnPeriods):
    totalReturn = capital * (1 + returnPeriods/100)**numberPeriods
    return totalReturn

def deposit_compounding(deposit, numberPeriods, returnPeriods):
    totalReturn = deposit * (1 + returnPeriods/100)**numberPeriods
    return totalReturn

# %%
# Data Assignment
x = np.linspace(0, numberPeriods,100)
y = []
y2 = (capital + numberPeriods) * (1 + returnPeriods/100)**x
y3 = (capital) * (1 + returnPeriods/100)**x

# %%
# f(x) for kodomain
capitalReturn = 0
depositReturn = 0
totalMoney = 0
for i in x:
    capitalReturn = initial_capital_compounding(capital,i,returnPeriods)
    if i != 0:
         for j in np.linspace(i-1,-1,100):  
             if i == numberPeriods and j == 0:
                 break
             depositReturn += deposit_compounding(deposit, j, returnPeriods)
    totalMoney = capitalReturn + depositReturn
    y.append(totalMoney)
    if i != numberPeriods:
        depositReturn = 0

# %%
print("len(x) =", len(x))
print("len(y) =", len(y))
print("len(y2) =", len(y2))
print("x shape =", np.shape(x))
print("y shape =", np.shape(y))
print(x)
print(y)
print(y2)
# Plotting
# plt.plot(x,y, label="DCA Compounding")
# plt.plot(x,y2, label="Normal Compounding")
# plt.title("DCA Compounding VS Normal Compounding")
# plt.xlabel("Sumbu X (Periode)")
# plt.ylabel("Sumbu Y (Hasil Compounding)")
# plt.legend()
# plt.grid(True)

# # # Menampilkan Plot
# plt.show()
# Out:
# len(x) = 100
# len(y) = 200
# len(y2) = 100
# x shape = (100,)
# y shape = (200,)
# [0.         0.05050505 0.1010101  0.15151515 0.2020202  0.25252525
#  0.3030303  0.35353535 0.4040404  0.45454545 0.50505051 0.55555556
#  0.60606061 0.65656566 0.70707071 0.75757576 0.80808081 0.85858586
#  0.90909091 0.95959596 1.01010101 1.06060606 1.11111111 1.16161616
#  1.21212121 1.26262626 1.31313131 1.36363636 1.41414141 1.46464646
#  1.51515152 1.56565657 1.61616162 1.66666667 1.71717172 1.76767677
#  1.81818182 1.86868687 1.91919192 1.96969697 2.02020202 2.07070707
#  2.12121212 2.17171717 2.22222222 2.27272727 2.32323232 2.37373737
#  2.42424242 2.47474747 2.52525253 2.57575758 2.62626263 2.67676768
#  2.72727273 2.77777778 2.82828283 2.87878788 2.92929293 2.97979798
#  3.03030303 3.08080808 3.13131313 3.18181818 3.23232323 3.28282828
#  3.33333333 3.38383838 3.43434343 3.48484848 3.53535354 3.58585859
#  3.63636364 3.68686869 3.73737374 3.78787879 3.83838384 3.88888889
#  3.93939394 3.98989899 4.04040404 4.09090909 4.14141414 4.19191919
#  4.24242424 4.29292929 4.34343434 4.39393939 4.44444444 4.49494949
#  4.54545455 4.5959596  4.64646465 4.6969697  4.74747475 4.7979798
#  4.84848485 4.8989899  4.94949495 5.        ]
# [np.float64(5.0), np.float64(104.03729683539416), np.float64(104.06470232426716), np.float64(104.09211746052847), np.float64(104.11954224798966), np.float64(104.14697669046419), np.float64(104.17442079176715), np.float64(104.20187455571512), np.float64(104.22933798612632), np.float64(104.2568110868206), np.float64(104.28429386161933), np.float64(104.31178631434562), np.float64(104.33928844882415), np.float64(104.36680026888111), np.float64(104.39432177834439), np.float64(104.42185298104344), np.float64(104.44939388080947), np.float64(104.47694448147512), np.float64(104.50450478687463), np.float64(104.53207480084397), np.float64(104.55965452722069), np.float64(104.58724396984398), np.float64(104.61484313255465), np.float64(104.64245201919498), np.float64(104.67007063360899), np.float64(104.69769897964233), np.float64(104.7253370611423), np.float64(104.75298488195767), np.float64(104.78064244593894), np.float64(104.80830975693821), np.float64(104.83598681880919), np.float64(104.86367363540732), np.float64(104.